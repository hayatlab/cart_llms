# %%
import pandas as pd
import requests
import time
from tqdm import tqdm

# Step 1: Read your CSV file
df = pd.read_csv('/data/ep924610/project_nb/paper_code/heatmap_results/skin_results.csv')
gene_symbols = df['Gene'].unique().tolist()

# Step 2: Convert gene symbols to UniProt IDs
def get_uniprot_id(gene_symbol):
    """Convert a gene symbol to UniProt ID using UniProt API"""
    url = f"https://rest.uniprot.org/uniprotkb/search?query=gene:{gene_symbol}+AND+reviewed:true+AND+organism_id:9606"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data['results']:
            return data['results'][0]['primaryAccession']
    return None

# Create a dictionary mapping gene symbols to UniProt IDs
print("Converting gene symbols to UniProt IDs...")
uniprot_dict = {}
for gene in tqdm(gene_symbols):
    uniprot_id = get_uniprot_id(gene)
    if uniprot_id:
        uniprot_dict[gene] = uniprot_id
    time.sleep(0.5)  # Avoid overwhelming the API
# Out:
# Converting gene symbols to UniProt IDs...
# 100%|███████████████████████████████████████████████████████████████████████████| 10837/10837 [2:11:14<00:00,  1.38it/s]

# %%
def get_protein_expression(uniprot_id):
    """Get protein expression data for a given UniProt ID"""
    base_url = "https://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata"
    
    # Create the param string with proper URL encoding
    query = f"/InputParams(PROTEINFILTER='{uniprot_id}',MS_LEVEL=1,TISSUE_ID_SELECTION='',TISSUE_CATEGORY_SELECTION='tissue;fluid',SCOPE_SELECTION=1,GROUP_BY_TISSUE=1,CALCULATION_METHOD=0,EXP_ID=-1)/Results"
    url = base_url + query + "?$select=UNIQUE_IDENTIFIER,TISSUE_ID,TISSUE_NAME,NORMALIZED_INTENSITY&$format=json"
    
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    return None

# Step 4: Calculate average expression scores
vital_tissues = ['brain', 'heart', 'lung']
results = []

print("Fetching protein expression data...")
for gene, uniprot_id in tqdm(uniprot_dict.items()):
    expression_data = get_protein_expression(uniprot_id)
    if not expression_data:
        continue
        
    vital_expressions = []
    non_vital_expressions = []
    
    for entry in expression_data.get('d', {}).get('results', []):
        tissue_name = entry.get('TISSUE_NAME', '').lower()
        
        # Convert expression value to float to avoid type issues
        try:
            expression = float(entry.get('NORMALIZED_INTENSITY', 0))
        except (TypeError, ValueError):
            # If conversion fails, use 0 as default
            expression = 0.0
        
        if any(vital in tissue_name for vital in vital_tissues):
            vital_expressions.append(expression)
        else:
            non_vital_expressions.append(expression)
    
    avg_vital = sum(vital_expressions) / len(vital_expressions) if vital_expressions else 0
    avg_non_vital = sum(non_vital_expressions) / len(non_vital_expressions) if non_vital_expressions else 0
    
    results.append({
        'Gene': gene,
        'UniProt_ID': uniprot_id,
        'Avg_Vital_Expression': avg_vital,
        'Avg_NonVital_Expression': avg_non_vital,
        'Vital_NonVital_Ratio': avg_vital / avg_non_vital if avg_non_vital > 0 else 0
    })
    
    time.sleep(1)  # Avoid overwhelming the API

# Create a DataFrame with the results
results_df = pd.DataFrame(results)
results_df.to_csv('/data/ep924610/project_nb/paper_code/protein_expression/protein_expression_results.csv', index=False)
print("Done! Results saved to protein_expression_results.csv")
# Out:
# Fetching protein expression data...
# 100%|███████████████████████████████████████████████████████████████████████████| 10667/10667 [5:37:16<00:00,  1.90s/it]
# Done! Results saved to protein_expression_results.csv

# %%
vital_expressions
# Out:
# [7.240338444260151, 7.114794495283671, 7.529530422277909]

# %%
expression_data
# Out:
# {'d': {'results': [{'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('148191442058377231')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000037',
#     'TISSUE_NAME': 'renal cell carcinoma cell',
#     'NORMALIZED_INTENSITY': '8.020890635771687'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('148191442058377232')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000047',
#     'TISSUE_NAME': 'adrenal gland',
#     'NORMALIZED_INTENSITY': '6.634121567667114'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('148191442058377233')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000066',
#     'TISSUE_NAME': 'amniocyte',
#     'NORMALIZED_INTENSITY': '8.458636793233453'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('148191442058377234')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000084',
#     'TISSUE_NAME': 'vermiform appendix',
#     'NORMALIZED_INTENSITY': '8.358336502202427'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('148191442058377235')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000091',
#     'TISSUE_NAME': 'ascites',
#     'NORMALIZED_INTENSITY': '7.005938677535159'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('148191442058377236')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000132',
#     'TISSUE_NAME': 'blood platelet',
#     'NORMALIZED_INTENSITY': '7.706155696809932'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('148191442058377237')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000141',
#     'TISSUE_NAME': 'bone marrow',
#     'NORMALIZED_INTENSITY': '8.970930037529087'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('148191442058377238')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000142',
#     'TISSUE_NAME': 'brain',
#     'NORMALIZED_INTENSITY': '7.240338444260151'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('148191442058377239')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000149',
#     'TISSUE_NAME': 'breast',
#     'NORMALIZED_INTENSITY': '6.013820433071692'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772310')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000150',
#     'TISSUE_NAME': 'breast cancer cell',
#     'NORMALIZED_INTENSITY': '7.457952636385239'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772311')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000198',
#     'TISSUE_NAME': 'cardia',
#     'NORMALIZED_INTENSITY': '6.6505432477057145'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772312')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000233',
#     'TISSUE_NAME': 'cerebral cortex',
#     'NORMALIZED_INTENSITY': '6.920343774107429'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772313')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000237',
#     'TISSUE_NAME': 'cerebrospinal fluid',
#     'NORMALIZED_INTENSITY': '6.775285782245606'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772314')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000269',
#     'TISSUE_NAME': 'colon',
#     'NORMALIZED_INTENSITY': '7.259772467374873'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772315')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000289',
#     'TISSUE_NAME': 'cytotoxic T-lymphocyte',
#     'NORMALIZED_INTENSITY': '8.179924971021222'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772316')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000365',
#     'TISSUE_NAME': 'duodenum',
#     'NORMALIZED_INTENSITY': '6.929398871302322'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772317')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000493',
#     'TISSUE_NAME': 'gall bladder',
#     'NORMALIZED_INTENSITY': '6.944000547858148'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772318')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000545',
#     'TISSUE_NAME': 'gut',
#     'NORMALIZED_INTENSITY': '7.383745017601815'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772319')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000562',
#     'TISSUE_NAME': 'heart',
#     'NORMALIZED_INTENSITY': '7.114794495283671'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772320')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000651',
#     'TISSUE_NAME': 'small intestine',
#     'NORMALIZED_INTENSITY': '8.087703969585586'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772321')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000662',
#     'TISSUE_NAME': 'nasopharynx',
#     'NORMALIZED_INTENSITY': '7.135447127274108'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772322')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000671',
#     'TISSUE_NAME': 'kidney',
#     'NORMALIZED_INTENSITY': '6.369011730811864'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772323')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000759',
#     'TISSUE_NAME': 'liver',
#     'NORMALIZED_INTENSITY': '6.6878823941231165'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772324')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000763',
#     'TISSUE_NAME': 'lung',
#     'NORMALIZED_INTENSITY': '7.529530422277909'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772325')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000776',
#     'TISSUE_NAME': 'B-lymphocyte',
#     'NORMALIZED_INTENSITY': '7.72686010129085'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772326')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000784',
#     'TISSUE_NAME': 'lymph node',
#     'NORMALIZED_INTENSITY': '7.258386518542698'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772327')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000868',
#     'TISSUE_NAME': 'milk',
#     'NORMALIZED_INTENSITY': '5.686814324655796'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772328')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000876',
#     'TISSUE_NAME': 'monocyte',
#     'NORMALIZED_INTENSITY': '8.579574307469795'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772329')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000907',
#     'TISSUE_NAME': 'myometrium',
#     'NORMALIZED_INTENSITY': '7.6075241389063155'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772330')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000914',
#     'TISSUE_NAME': 'natural killer cell',
#     'NORMALIZED_INTENSITY': '8.180252783465848'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772331')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000959',
#     'TISSUE_NAME': 'esophagus',
#     'NORMALIZED_INTENSITY': '6.346282118577568'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772332')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000975',
#     'TISSUE_NAME': 'ovary',
#     'NORMALIZED_INTENSITY': '7.123216103072194'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772333')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000980',
#     'TISSUE_NAME': 'oviduct',
#     'NORMALIZED_INTENSITY': '7.7930893079300185'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772334')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000988',
#     'TISSUE_NAME': 'pancreas',
#     'NORMALIZED_INTENSITY': '6.865866017092326'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772335')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0000991',
#     'TISSUE_NAME': 'pancreatic islet',
#     'NORMALIZED_INTENSITY': '6.7832830482942965'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772336')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001078',
#     'TISSUE_NAME': 'placenta',
#     'NORMALIZED_INTENSITY': '6.761100423524244'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772337')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001086',
#     'TISSUE_NAME': 'embryonic stem cell',
#     'NORMALIZED_INTENSITY': '6.138961420239538'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772338')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001129',
#     'TISSUE_NAME': 'prostate gland',
#     'NORMALIZED_INTENSITY': '6.639685424149065'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772339')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001158',
#     'TISSUE_NAME': 'rectum',
#     'NORMALIZED_INTENSITY': '6.459255806559023'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772340')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001175',
#     'TISSUE_NAME': 'retina',
#     'NORMALIZED_INTENSITY': '5.261662881682198'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772341')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001202',
#     'TISSUE_NAME': 'saliva',
#     'NORMALIZED_INTENSITY': '6.575514121166975'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772342')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001203',
#     'TISSUE_NAME': 'salivary gland',
#     'NORMALIZED_INTENSITY': '6.530126721866319'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772343')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001234',
#     'TISSUE_NAME': 'seminal vesicle',
#     'NORMALIZED_INTENSITY': '6.584329698030535'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772344')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001253',
#     'TISSUE_NAME': 'skin',
#     'NORMALIZED_INTENSITY': '7.466893365163633'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772345')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001260',
#     'TISSUE_NAME': 'smooth muscle',
#     'NORMALIZED_INTENSITY': '8.12056559856026'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772346')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001279',
#     'TISSUE_NAME': 'spinal cord',
#     'NORMALIZED_INTENSITY': '5.900366552198096'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772347')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001281',
#     'TISSUE_NAME': 'spleen',
#     'NORMALIZED_INTENSITY': '7.602329709500772'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772348')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001307',
#     'TISSUE_NAME': 'stomach',
#     'NORMALIZED_INTENSITY': '7.121722393244717'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772349')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001339',
#     'TISSUE_NAME': 'synovia',
#     'NORMALIZED_INTENSITY': '8.158761120320118'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772350')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001363',
#     'TISSUE_NAME': 'testis',
#     'NORMALIZED_INTENSITY': '6.375339977994608'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772351')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001379',
#     'TISSUE_NAME': 'thyroid gland',
#     'NORMALIZED_INTENSITY': '7.494906711991414'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772352')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001387',
#     'TISSUE_NAME': 'tonsil',
#     'NORMALIZED_INTENSITY': '7.6775587301372346'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772353')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001409',
#     'TISSUE_NAME': 'ureter',
#     'NORMALIZED_INTENSITY': '8.135845661537447'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772354')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001418',
#     'TISSUE_NAME': 'urinary bladder',
#     'NORMALIZED_INTENSITY': '6.351838878410058'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772355')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001421',
#     'TISSUE_NAME': 'uterine cervix',
#     'NORMALIZED_INTENSITY': '6.174497871453922'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772356')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001422',
#     'TISSUE_NAME': 'uterine endometrium',
#     'NORMALIZED_INTENSITY': '7.811606993288941'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772357')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001424',
#     'TISSUE_NAME': 'uterus',
#     'NORMALIZED_INTENSITY': '7.68508157699338'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772358')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001451',
#     'TISSUE_NAME': 'vitreous humor',
#     'NORMALIZED_INTENSITY': '5.490064927568708'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772359')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001487',
#     'TISSUE_NAME': 'adipose tissue',
#     'NORMALIZED_INTENSITY': '7.82036297702369'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772360')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0001775',
#     'TISSUE_NAME': 'oral epithelium',
#     'NORMALIZED_INTENSITY': '8.01252247590687'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772361')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0002417',
#     'TISSUE_NAME': 'helper T-lymphocyte',
#     'NORMALIZED_INTENSITY': '8.558941618093781'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772362')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0002807',
#     'TISSUE_NAME': 'prefrontal cortex',
#     'NORMALIZED_INTENSITY': '6.693793653211941'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772363')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0003445',
#     'TISSUE_NAME': 'carotid atherosclerotic plaque',
#     'NORMALIZED_INTENSITY': '7.80109741841026'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772364')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'BTO:0004122',
#     'TISSUE_NAME': 'bone marrow stromal cell',
#     'NORMALIZED_INTENSITY': '6.1186140336666774'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772365')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'PDB:200000',
#     'TISSUE_NAME': 'proximal fluid (coronary sinus)',
#     'NORMALIZED_INTENSITY': '6.452808110284753'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772366')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'PDB:200048',
#     'TISSUE_NAME': 'synovial fluid',
#     'NORMALIZED_INTENSITY': '6.035563346000053'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772367')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'PDB:200049',
#     'TISSUE_NAME': 'arachnoid cyst',
#     'NORMALIZED_INTENSITY': '6.735731051474356'},
#    {'__metadata': {'type': 'proteomicsdb.logic.api.proteinexpression.CA_EXPRESSION_PROFILE_APIType',
#      'uri': "http://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata/CA_EXPRESSION_PROFILE_API('1481914420583772368')"},
#     'UNIQUE_IDENTIFIER': 'P62328',
#     'TISSUE_ID': 'PDB:201191',
#     'TISSUE_NAME': 'aqueous humour',
#     'NORMALIZED_INTENSITY': '6.846768714317259'}]}}

# %%
# Sort the results by vital tissue expression (from highest to lowest)
sorted_results = results_df.sort_values(by='Avg_Vital_Expression', ascending=True)

# Print the top 10 genes with highest expression in vital tissues
print("\nTop 10 genes with highest expression in vital tissues:")
top_10 = sorted_results.head(10)
print(top_10[['Gene', 'UniProt_ID', 'Avg_Vital_Expression', 'Avg_NonVital_Expression', 'Vital_NonVital_Ratio']])
# Out:
# Top 10 genes with highest expression in vital tissues:
#          Gene UniProt_ID  Avg_Vital_Expression  Avg_NonVital_Expression  \
# 5814     LCOR     Q96JN0                   0.0                 3.636068
# 4574   ZNF461     Q8TAF7                   0.0                 0.000000
# 7090     IL24     Q13007                   0.0                 3.550842
# 9529    SMAD7     O15105                   0.0                 0.000000
# 7088     KLF7     O75840                   0.0                 4.832241
# 7939   ZBTB46     Q86UZ6                   0.0                 3.630000
# 7087    CNTD1     Q8N815                   0.0                 0.000000
# 7084   ARRDC4     Q8NCT1                   0.0                 0.000000
# 7079   ZNF630     Q2M218                   0.0                 3.251181
# 7078  SLC35E4     Q6ICL7                   0.0                 4.265198
#
#       Vital_NonVital_Ratio
# 5814                   0.0
# 4574                   0.0
# 7090                   0.0
# 9529                   0.0
# 7088                   0.0
# 7939                   0.0
# 7087                   0.0
# 7084                   0.0
# 7079                   0.0
# 7078                   0.0

# %%
# Sort the results by vital tissue expression (from highest to lowest)
sorted_results = results_df.sort_values(by='Avg_Vital_Expression', ascending=True)

# Reset index to have row numbers from 0
sorted_results = sorted_results.reset_index(drop=True)

# Find the rank of GPNMB
gpnmb_row = sorted_results[sorted_results['Gene'] == 'GPNMB']
if not gpnmb_row.empty:
    gpnmb_index = gpnmb_row.index[0]
    gpnmb_rank = gpnmb_index + 1  # +1 because index is 0-based
    
    print(f"\nGPNMB rank when sorted by vital expression: {gpnmb_rank} out of {len(sorted_results)}")
    print("\nGPNMB details:")
    print(gpnmb_row[['Gene', 'UniProt_ID', 'Avg_Vital_Expression', 'Avg_NonVital_Expression', 'Vital_NonVital_Ratio']])
else:
    print("\nGPNMB not found in the results")
# Out:
# GPNMB rank when sorted by vital expression: 5785 out of 10667
#
# GPNMB details:
#        Gene UniProt_ID  Avg_Vital_Expression  Avg_NonVital_Expression  \
# 5784  GPNMB     Q14956              4.316531                 4.717716
#
#       Vital_NonVital_Ratio
# 5784              0.914962

# %%
gpnmb_row = sorted_results[sorted_results['Gene'] == 'ERBB3']
if not gpnmb_row.empty:
    gpnmb_index = gpnmb_row.index[0]
    gpnmb_rank = gpnmb_index + 1  # +1 because index is 0-based
    
    print(f"\nGPNMB rank when sorted by vital expression: {gpnmb_rank} out of {len(sorted_results)}")
    print("\nGPNMB details:")
    print(gpnmb_row[['Gene', 'UniProt_ID', 'Avg_Vital_Expression', 'Avg_NonVital_Expression', 'Vital_NonVital_Ratio']])
else:
    print("\nGPNMB not found in the results")
# Out:
# GPNMB rank when sorted by vital expression: 2621 out of 10667
#
# GPNMB details:
#        Gene UniProt_ID  Avg_Vital_Expression  Avg_NonVital_Expression  \
# 2620  ERBB3     P21860              3.507384                 3.756212
#
#       Vital_NonVital_Ratio
# 2620              0.933756

# %%
def get_protein_expression(uniprot_id):
    """Get protein expression data for a given UniProt ID"""
    base_url = "https://www.proteomicsdb.org/proteomicsdb/logic/api/proteinexpression.xsodata"
    
    # Create the param string with proper URL encoding
    query = f"/InputParams(PROTEINFILTER='{uniprot_id}',MS_LEVEL=1,TISSUE_ID_SELECTION='',TISSUE_CATEGORY_SELECTION='tissue;fluid',SCOPE_SELECTION=1,GROUP_BY_TISSUE=1,CALCULATION_METHOD=0,EXP_ID=-1)/Results"
    url = base_url + query + "?$select=UNIQUE_IDENTIFIER,TISSUE_ID,TISSUE_NAME,NORMALIZED_INTENSITY&$format=json"
    
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    return None

# Step 4: Calculate average expression scores and store individual tissue data
vital_tissues = ['brain', 'heart', 'lung']
results = []
all_tissue_names = set()  # To keep track of all tissues encountered

# First pass: collect all unique tissue names
print("First pass: collecting all tissue names...")
for gene, uniprot_id in tqdm(list(uniprot_dict.items())[:10]):  # Sample with first 10 genes to discover tissue names
    expression_data = get_protein_expression(uniprot_id)
    if not expression_data:
        continue
        
    for entry in expression_data.get('d', {}).get('results', []):
        tissue_name = entry.get('TISSUE_NAME', '').lower().replace(' ', '_').replace('-', '_')
        all_tissue_names.add(tissue_name)
    
    time.sleep(0.01)  # Avoid overwhelming the API

all_tissue_names = sorted(list(all_tissue_names))
print(f"Found {len(all_tissue_names)} unique tissues")

# Second pass: collect expression data for all genes
print("Second pass: fetching protein expression data for all genes...")
for gene, uniprot_id in tqdm(uniprot_dict.items()):
    expression_data = get_protein_expression(uniprot_id)
    if not expression_data:
        continue
        
    vital_expressions = []
    non_vital_expressions = []
    
    # Initialize the result dictionary with gene info and zeros for all tissues
    result = {
        'Gene': gene,
        'UniProt_ID': uniprot_id
    }
    
    # Add a column for each tissue with default value 0
    for tissue in all_tissue_names:
        result[f'tissue_{tissue}'] = 0.0
    
    # Fill in the actual expression values
    for entry in expression_data.get('d', {}).get('results', []):
        tissue_name = entry.get('TISSUE_NAME', '').lower()
        tissue_key = tissue_name.replace(' ', '_').replace('-', '_')
        
        # Convert expression value to float
        try:
            expression = float(entry.get('NORMALIZED_INTENSITY', 0))
        except (TypeError, ValueError):
            expression = 0.0
        
        # Store the expression value in the tissue-specific column
        result[f'tissue_{tissue_key}'] = expression
        
        # Also keep track for vital vs non-vital calculation
        if any(vital in tissue_name for vital in vital_tissues):
            vital_expressions.append(expression)
        else:
            non_vital_expressions.append(expression)
    
    # Calculate averages
    avg_vital = sum(vital_expressions) / len(vital_expressions) if vital_expressions else 0
    avg_non_vital = sum(non_vital_expressions) / len(non_vital_expressions) if non_vital_expressions else 0
    
    # Add the summary columns
    result['Avg_Vital_Expression'] = avg_vital
    result['Avg_NonVital_Expression'] = avg_non_vital
    result['Vital_NonVital_Ratio'] = avg_vital / avg_non_vital if avg_non_vital > 0 else 0
    
    results.append(result)
    
    time.sleep(0.01)  # Avoid overwhelming the API

# Create a DataFrame with the results
results_df = pd.DataFrame(results)
results_df.to_csv('/data/ep924610/project_nb/paper_code/protein_expression/protein_expression_results_with_tissues.csv', index=False)
print("Done! Results saved to protein_expression_results_with_tissues.csv")

# Example of how to find genes with high expression in a specific tissue
def find_genes_by_tissue(df, tissue_name, min_expression=7.0):
    """Find genes with expression above threshold in a specific tissue"""
    tissue_col = f'tissue_{tissue_name.lower().replace(" ", "_").replace("-", "_")}'
    if tissue_col not in df.columns:
        print(f"Tissue {tissue_name} not found. Available tissues: {[col.replace('tissue_', '') for col in df.columns if col.startswith('tissue_')]}")
        return pd.DataFrame()
    
    return df[df[tissue_col] >= min_expression].sort_values(by=tissue_col, ascending=False)

# Example usage:
# high_brain_expression = find_genes_by_tissue(results_df, 'brain', min_expression=8.0)
# print(high_brain_expression[['Gene', 'UniProt_ID', 'tissue_brain']].head(10))
# Out:
# First pass: collecting all tissue names...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:07<00:00,  1.25it/s]
# Found 69 unique tissues
# Second pass: fetching protein expression data for all genes...
# 100%|███████████████████████████████████████████████████████████████████████████| 10667/10667 [2:49:47<00:00,  1.05it/s]
# Done! Results saved to protein_expression_results_with_tissues.csv

# %%
import pandas as pd
import requests
import time
from tqdm import tqdm

# %%
results_df = pd.read_csv("/data/ep924610/project_nb/paper_code/protein_expression/protein_expression_results_with_tissues.csv")

# %%
results_df[["Gene","Avg_Vital_Expression", "Avg_NonVital_Expression"]]
# Out:
#           Gene  Avg_Vital_Expression
# 0        GPNMB              4.316531
# 1         FMN1              3.398871
# 2      TMEM117              3.585851
# 3        GPM6B              5.110041
# 4         SGCD              5.008843
# ...        ...                   ...
# 10662     SRGN              4.677084
# 10663    ZFP36              3.904304
# 10664  TNFAIP3              4.082586
# 10665   NFKBIA              4.306088
# 10666   TMSB4X              7.294888
#
# [10667 rows x 2 columns]

# %%
results_df[["Gene","Avg_Vital_Expression", "Avg_NonVital_Expression"]].sort_values(by="Avg_Vital_Expression", ascending=True)
# Out:
#          Gene  Avg_Vital_Expression  Avg_NonVital_Expression
# 5814     LCOR              0.000000                 3.636068
# 4574   ZNF461              0.000000                 0.000000
# 7090     IL24              0.000000                 3.550842
# 9529    SMAD7              0.000000                 0.000000
# 7088     KLF7              0.000000                 4.832241
# ...       ...                   ...                      ...
# 9705    YWHAZ              7.327124                 7.159622
# 10555    TPI1              7.341830                 6.915559
# 10540  TUBB4B              7.367555                 7.202583
# 10457    TUBB              7.386673                 7.088919
# 10571   GAPDH              7.521045                 7.411896
#
# [10667 rows x 3 columns]
